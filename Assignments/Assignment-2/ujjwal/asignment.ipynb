# %% [markdown]
# ## Section 1: Python Basics
# Learn about Python syntax, data types, and basic programming constructs.

# %% [markdown]
# ## Section 5: Exercises
# Practice problems to reinforce concepts in NumPy, Pandas, and Matplotlib.

# %%
# 1. Create a NumPy array of 10 numbers and calculate mean and std deviation
arr = [1,2,3,4,5,6,1,10,12,17]
mean = np.mean(arr)
std= np.std(arr)
mean, std
# 2. Load a CSV file using Pandas (or create one manually)
df = pd.read_csv("student_age_marks.csv")
df
# 3. Plot a histogram of a numerical column using Matplotlib
plt.hist(df['Marks'], bins=5)
plt.title("Histogram of Marks")
plt.xlabel("Marks")
plt.ylabel("Frequency")
plt.show()
# 4. Filter a DataFrame for rows with marks > 90
dffil= df[df['Marks']>90]
print("filtered data", dffil)
# 5. Use a scatter plot to visualize relationship between Age and Marks
plt.scatter(df['Age'], df['Marks'])
plt.title("Age vs Marks")
plt.xlabel("Age")
plt.ylabel("Marks")
plt.show()
# 6. Try reading an Excel file using pd.read_excel if you have one
xlfile = pd.read_excel('midsem.xlsx')

# 7. Merge two DataFrames on a common column
result = pd.merge(df, xlfile, on='StudentID')
result
# 8. Handle missing values in a DataFrame
# 9. Simulate a grayscale image and display its pixel values using NumPy
# Out:
# filtered data    StudentID  Age  Marks
# 1       S002   19   93.9
# 2       S003   17   99.7
# 4       S005   19  100.0
# 5       S006   16   97.3
# 9       S010   19   94.2
# 10      S011   18   94.7
# 11      S012   17   92.4
# 16      S017   18   91.5
# 17      S018   19   93.9
# 18      S019   15  100.0
# 21      S022   19   99.2
# 22      S023   18   98.7
# 23      S024   15   97.9
# 24      S025   15   91.2
# 25      S026   17   93.2
# 32      S033   18   99.6
# 35      S036   19   91.4
# 36      S037   17   92.2
# 37      S038   19   92.4
# 43      S044   16  100.0
# 54      S055   17   95.9
# 58      S059   18  100.0
# 61      S062   18  100.0
# 62      S063   19  100.0
# 65      S066   18   91.7
# 69      S070   18  100.0
# 71      S072   19   97.2
# 72      S073   19  100.0
# 74      S075   19   95.3
# 77      S078   18   94.3
# 80      S081   19  100.0
# 83      S084   19   92.3
# 88      S089   18  100.0
# 89      S090   17   93.7
# 93      S094   17   92.4
# 96      S097   19  100.0
#    StudentID  Age  Marks      Roll No  Mid_Sem_Marks  Total marks
# 0       S001   18   81.0     200178.0           22.0           35
# 1       S002   19   93.9          NaN           28.0           35
# 2       S003   17   99.7     200320.0           21.0           35
# 3       S004   19   83.8     210307.0           30.0           35
# 4       S005   19  100.0     210366.0           23.0           35
# ..       ...  ...    ...          ...            ...          ...
# 95      S096   17   86.2  241080069.0           22.0           35
# 96      S097   19  100.0  241080081.0           22.0           35
# 97      S098   16   81.5  241080088.0           26.5           35
# 98      S099   16   74.0  241080105.0           29.0           35
# 99      S100   15   66.5  241270003.0           18.0           35
#
# [100 rows x 6 columns]

# %%
import numpy as np
import matplotlib.pyplot as plt

# Generate a 5x5 grayscale image with random pixel values
gray_image = np.random.randint(0, 256, (5, 5), dtype=np.uint8)

# Display the image
plt.imshow(gray_image, cmap='gray', vmin=0, vmax=255)
plt.colorbar(label='Pixel Intensity')
plt.title('Simulated Grayscale Image')
plt.axis('off')  # Hide axis ticks
plt.show()
