# %%
# Q8: Handle Missing Values in a DataFrame

import pandas as pd
import numpy as np
from io import StringIO

# Data input (use full data from the prompt)
data = """StudentID,Age,Marks
S001,18,81.0
S002,19,93.9
S003,17,99.7
S004,19,83.8
S005,19,100.0
S006,16,97.3
S007,17,89.6
S008,17,68.2
S009,17,88.3
S010,19,94.2
S011,18,94.7
S012,17,92.4
S013,19,87.2
S014,16,71.6
S015,18,88.5
S016,16,70.3
S017,18,91.5
S018,19,93.9
S019,15,100.0
S020,18,79.7
S021,16,72.2
S022,19,99.2
S023,18,98.7
S024,15,97.9
S025,15,91.2
S026,17,93.2
S027,17,87.9
S028,16,89.0
S029,18,83.9
S030,18,86.8
S031,17,70.2
S032,18,87.7
S033,18,99.6
S034,15,72.9
S035,17,77.3
S036,19,91.4
S037,17,92.2
S038,19,92.4
S039,15,83.5
S040,16,66.9
S041,18,81.3
S042,15,69.9
S043,18,76.9
S044,16,100.0
S045,16,69.0
S046,15,84.1
S047,16,73.3
S048,19,89.9
S049,16,83.0
S050,18,75.4
S051,18,83.4
S052,18,88.5
S053,18,81.5
S054,19,86.8
S055,17,95.9
S056,15,85.0
S057,18,85.6
S058,16,79.2
S059,18,100.0
S060,16,65.7
S061,16,83.4
S062,18,100.0
S063,19,100.0
S064,16,60.6
S065,16,72.4
S066,18,91.7
S067,16,66.8
S068,16,73.3
S069,18,88.6
S070,18,100.0
S071,15,74.5
S072,19,97.2
S073,19,100.0
S074,16,85.4
S075,19,95.3
S076,16,68.0
S077,15,82.9
S078,18,94.3
S079,18,79.0
S080,18,83.2
S081,19,100.0
S082,15,81.1
S083,19,87.8
S084,19,92.3
S085,15,73.6
S086,15,81.2
S087,15,87.5
S088,15,75.7
S089,18,100.0
S090,17,93.7
S091,17,87.1
S092,15,60.6
S093,17,74.7
S094,17,92.4
S095,15,57.9
S096,17,86.2
S097,19,100.0
S098,16,81.5
S099,16,74.0
S100,15,66.5
"""

df = pd.read_csv(StringIO(data))

# Simulate missing values
df.loc[10, 'Marks'] = np.nan
df.loc[20, 'Age'] = np.nan

print("Before handling missing values:\n")
print(df.isnull().sum())

# Handle missing values
df['Marks'].fillna(df['Marks'].mean(), inplace=True)
df['Age'].fillna(df['Age'].mode()[0], inplace=True)

print("\nAfter handling missing values:\n")
print(df.isnull().sum())
# Out:
# Before handling missing values:
#
# StudentID    0
# Age          1
# Marks        1
# dtype: int64
#
# After handling missing values:
#
# StudentID    0
# Age          0
# Marks        0
# dtype: int64
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_16404\636406557.py:121: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Marks'].fillna(df['Marks'].mean(), inplace=True)
# ...

# %%
# 5. Use a scatter plot to visualize relationship between Age and Marks
import pandas as pd
import matplotlib.pyplot as plt
from io import StringIO

# Your full data as a string
data = """StudentID,Age,Marks
S001,18,81.0
S002,19,93.9
S003,17,99.7
S004,19,83.8
S005,19,100.0
S006,16,97.3
S007,17,89.6
S008,17,68.2
S009,17,88.3
S010,19,94.2
S011,18,94.7
S012,17,92.4
S013,19,87.2
S014,16,71.6
S015,18,88.5
S016,16,70.3
S017,18,91.5
S018,19,93.9
S019,15,100.0
S020,18,79.7
S021,16,72.2
S022,19,99.2
S023,18,98.7
S024,15,97.9
S025,15,91.2
S026,17,93.2
S027,17,87.9
S028,16,89.0
S029,18,83.9
S030,18,86.8
S031,17,70.2
S032,18,87.7
S033,18,99.6
S034,15,72.9
S035,17,77.3
S036,19,91.4
S037,17,92.2
S038,19,92.4
S039,15,83.5
S040,16,66.9
S041,18,81.3
S042,15,69.9
S043,18,76.9
S044,16,100.0
S045,16,69.0
S046,15,84.1
S047,16,73.3
S048,19,89.9
S049,16,83.0
S050,18,75.4
S051,18,83.4
S052,18,88.5
S053,18,81.5
S054,19,86.8
S055,17,95.9
S056,15,85.0
S057,18,85.6
S058,16,79.2
S059,18,100.0
S060,16,65.7
S061,16,83.4
S062,18,100.0
S063,19,100.0
S064,16,60.6
S065,16,72.4
S066,18,91.7
S067,16,66.8
S068,16,73.3
S069,18,88.6
S070,18,100.0
S071,15,74.5
S072,19,97.2
S073,19,100.0
S074,16,85.4
S075,19,95.3
S076,16,68.0
S077,15,82.9
S078,18,94.3
S079,18,79.0
S080,18,83.2
S081,19,100.0
S082,15,81.1
S083,19,87.8
S084,19,92.3
S085,15,73.6
S086,15,81.2
S087,15,87.5
S088,15,75.7
S089,18,100.0
S090,17,93.7
S091,17,87.1
S092,15,60.6
S093,17,74.7
S094,17,92.4
S095,15,57.9
S096,17,86.2
S097,19,100.0
S098,16,81.5
S099,16,74.0
S100,15,66.5"""

# Load data into DataFrame
df = pd.read_csv(StringIO(data))

# Create scatter plot
plt.figure(figsize=(10, 6))
plt.scatter(df['Age'], df['Marks'], color='darkgreen', alpha=0.6, edgecolors='black')
plt.title('Scatter Plot of Age vs Marks')
plt.xlabel('Age')
plt.ylabel('Marks')
plt.grid(True)
plt.show()

# %%
# Q9: Simulate a Grayscale Image Using NumPy and Marks
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from io import StringIO

# Load only Marks from data
data = """StudentID,Age,Marks
S001,18,81.0
S002,19,93.9
S003,17,99.7
S004,19,83.8
S005,19,100.0
S006,16,97.3
S007,17,89.6
S008,17,68.2
S009,17,88.3
S010,19,94.2
S011,18,94.7
S012,17,92.4
S013,19,87.2
S014,16,71.6
S015,18,88.5
S016,16,70.3
S017,18,91.5
S018,19,93.9
S019,15,100.0
S020,18,79.7
S021,16,72.2
S022,19,99.2
S023,18,98.7
S024,15,97.9
S025,15,91.2
S026,17,93.2
S027,17,87.9
S028,16,89.0
S029,18,83.9
S030,18,86.8
S031,17,70.2
S032,18,87.7
S033,18,99.6
S034,15,72.9
S035,17,77.3
S036,19,91.4
S037,17,92.2
S038,19,92.4
S039,15,83.5
S040,16,66.9
S041,18,81.3
S042,15,69.9
S043,18,76.9
S044,16,100.0
S045,16,69.0
S046,15,84.1
S047,16,73.3
S048,19,89.9
S049,16,83.0
S050,18,75.4
S051,18,83.4
S052,18,88.5
S053,18,81.5
S054,19,86.8
S055,17,95.9
S056,15,85.0
S057,18,85.6
S058,16,79.2
S059,18,100.0
S060,16,65.7
S061,16,83.4
S062,18,100.0
S063,19,100.0
S064,16,60.6
S065,16,72.4
S066,18,91.7
S067,16,66.8
S068,16,73.3
S069,18,88.6
S070,18,100.0
S071,15,74.5
S072,19,97.2
S073,19,100.0
S074,16,85.4
S075,19,95.3
S076,16,68.0
S077,15,82.9
S078,18,94.3
S079,18,79.0
S080,18,83.2
S081,19,100.0
S082,15,81.1
S083,19,87.8
S084,19,92.3
S085,15,73.6
S086,15,81.2
S087,15,87.5
S088,15,75.7
S089,18,100.0
S090,17,93.7
S091,17,87.1
S092,15,60.6
S093,17,74.7
S094,17,92.4
S095,15,57.9
S096,17,86.2
S097,19,100.0
S098,16,81.5
S099,16,74.0
S100,15,66.5
"""

df = pd.read_csv(StringIO(data))

# Extract marks and simulate image
marks = df['Marks'].values
n = int(np.floor(np.sqrt(len(marks))))
image = marks[:n*n].reshape(n, n)

# Print grayscale image pixel values
print("Grayscale image pixel values:")
print(image)

# Display as image
plt.imshow(image, cmap='gray')
plt.title("Grayscale Image from Marks")
plt.colorbar(label='Marks')
plt.show()
# Out:
# Grayscale image pixel values:
# [[ 81.   93.9  99.7  83.8 100.   97.3  89.6  68.2  88.3  94.2]
#  [ 94.7  92.4  87.2  71.6  88.5  70.3  91.5  93.9 100.   79.7]
#  [ 72.2  99.2  98.7  97.9  91.2  93.2  87.9  89.   83.9  86.8]
#  [ 70.2  87.7  99.6  72.9  77.3  91.4  92.2  92.4  83.5  66.9]
#  [ 81.3  69.9  76.9 100.   69.   84.1  73.3  89.9  83.   75.4]
#  [ 83.4  88.5  81.5  86.8  95.9  85.   85.6  79.2 100.   65.7]
#  [ 83.4 100.  100.   60.6  72.4  91.7  66.8  73.3  88.6 100. ]
#  [ 74.5  97.2 100.   85.4  95.3  68.   82.9  94.3  79.   83.2]
#  [100.   81.1  87.8  92.3  73.6  81.2  87.5  75.7 100.   93.7]
#  [ 87.1  60.6  74.7  92.4  57.9  86.2 100.   81.5  74.   66.5]]

# %%
# 3. Plot a histogram of a numerical column using Matplotlib
import pandas as pd
import matplotlib.pyplot as plt
from io import StringIO

# CSV data as a string
data = """
StudentID,Age,Marks
S001,18,81.0
S002,19,93.9
S003,17,99.7
S004,19,83.8
S005,19,100.0
S006,16,97.3
S007,17,89.6
S008,17,68.2
S009,17,88.3
S010,19,94.2
S011,18,94.7
S012,17,92.4
S013,19,87.2
S014,16,71.6
S015,18,88.5
S016,16,70.3
S017,18,91.5
S018,19,93.9
S019,15,100.0
S020,18,79.7
S021,16,72.2
S022,19,99.2
S023,18,98.7
S024,15,97.9
S025,15,91.2
S026,17,93.2
S027,17,87.9
S028,16,89.0
S029,18,83.9
S030,18,86.8
S031,17,70.2
S032,18,87.7
S033,18,99.6
S034,15,72.9
S035,17,77.3
S036,19,91.4
S037,17,92.2
S038,19,92.4
S039,15,83.5
S040,16,66.9
S041,18,81.3
S042,15,69.9
S043,18,76.9
S044,16,100.0
S045,16,69.0
S046,15,84.1
S047,16,73.3
S048,19,89.9
S049,16,83.0
S050,18,75.4
S051,18,83.4
S052,18,88.5
S053,18,81.5
S054,19,86.8
S055,17,95.9
S056,15,85.0
S057,18,85.6
S058,16,79.2
S059,18,100.0
S060,16,65.7
S061,16,83.4
S062,18,100.0
S063,19,100.0
S064,16,60.6
S065,16,72.4
S066,18,91.7
S067,16,66.8
S068,16,73.3
S069,18,88.6
S070,18,100.0
S071,15,74.5
S072,19,97.2
S073,19,100.0
S074,16,85.4
S075,19,95.3
S076,16,68.0
S077,15,82.9
S078,18,94.3
S079,18,79.0
S080,18,83.2
S081,19,100.0
S082,15,81.1
S083,19,87.8
S084,19,92.3
S085,15,73.6
S086,15,81.2
S087,15,87.5
S088,15,75.7
S089,18,100.0
S090,17,93.7
S091,17,87.1
S092,15,60.6
S093,17,74.7
S094,17,92.4
S095,15,57.9
S096,17,86.2
S097,19,100.0
S098,16,81.5
S099,16,74.0
S100,15,66.5
"""

# Read the data into a DataFrame
df = pd.read_csv(StringIO(data))

# Plot the histogram of the Marks column
plt.figure(figsize=(10, 6))
plt.hist(df['Marks'], bins=10, color='skyblue', edgecolor='black')
plt.title("Histogram of Student Marks")
plt.xlabel("Marks")
plt.ylabel("Number of Students")
plt.grid(True)
plt.show()

# %%
# 1. Create a NumPy array of 10 numbers and calculate mean and std deviation
import pandas as pd
import numpy as np
from io import StringIO

# Raw data as string
data = """StudentID,Age,Marks
S001,18,81.0
S002,19,93.9
S003,17,99.7
S004,19,83.8
S005,19,100.0
S006,16,97.3
S007,17,89.6
S008,17,68.2
S009,17,88.3
S010,19,94.2
"""

# Load data into DataFrame
df = pd.read_csv(StringIO(data))

# Extract marks of first 10 students as NumPy array
marks_array = df["Marks"].to_numpy()

# Calculate mean and standard deviation
mean_marks = np.mean(marks_array)
std_dev_marks = np.std(marks_array)

# Output
print("Marks Array:", marks_array)
print("Mean:", mean_marks)
print("Standard Deviation:", std_dev_marks)

# %%
# 2. Load a CSV file using Pandas (or create one manually)
import pandas as pd

data = {
    "Name": ["Ankit", "kumar", "saini", "lalit"],
    "Age": [18, 19, 20, 21],
    "Marks": [100, 99, 98, 97]
}
df = pd.DataFrame(data)
df.to_csv("students.csv", index=False)

df_l = pd.read_csv("students.csv")
print(df_l)

# %%
# 4. Filter a DataFrame for rows with marks > 90
import pandas as pd
df = pd.read_excel(r"C:\Users\Lenovo\Downloads\student_age_marks.xlsx")
filtered_df = df[df['Marks'] > 90]
print(filtered_df)

# %%
# 6. Try reading an Excel file using pd.read_excel if you have one
import pandas as pd

df = pd.read_excel(r"C:\Users\Lenovo\Downloads\student_age_marks.xlsx")
print(df.head(50))

# %%
# 7. Merge two DataFrames on a common column
import pandas as pd

df1 = pd.DataFrame({
    'StudentID': ['S001', 'S002', 'S003', 'S004', 'S005'],
    'Age': [18, 19, 17, 19, 19],
    'Marks': [81, 93.9, 99.7, 83.8, 100]
})

df2 = pd.DataFrame({
    'StudentID': ['S001', 'S002', 'S003', 'S004', 'S005'],
    'Subject': ['Math', 'Science', 'English', 'Physics', 'Chemistry']
})
merged_df = pd.merge(df1, df2, on='StudentID', how='inner')  
print(merged_df)
